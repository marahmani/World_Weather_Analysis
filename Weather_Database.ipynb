# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# # Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
# for coordinate in coordinates:
#     # Use the citipy module to identify the nearest city to the current coordinate
#     city = # YOUR CODE HERE
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         # YOUR CODE HERE

# # Print the city count to confirm sufficient count
# # YOUR CODE HERE
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | colares
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | kupang
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | ahipara
# Processing Record 11 of Set 1 | hagenow
# Processing Record 12 of Set 1 | las navas
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | kensington
# Processing Record 15 of Set 1 | pedernales
# Processing Record 16 of Set 1 | westport
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | lublin
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | ambon
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | isangel
# Processing Record 30 of Set 1 | fairbanks
# Processing Record 31 of Set 1 | kungurtug
# Processing Record 32 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | black river
# Processing Record 35 of Set 1 | shalakusha
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | vardo
# Processing Record 38 of Set 1 | wanning
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | gamba
# Processing Record 43 of Set 1 | young
# Processing Record 44 of Set 1 | kavaratti
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | letterkenny
# Processing Record 48 of Set 1 | svetlogorsk
# Processing Record 49 of Set 1 | caravelas
# Processing Record 50 of Set 1 | san cristobal
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | itarema
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | nevers
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | upata
# Processing Record 9 of Set 2 | agadez
# Processing Record 10 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 2 | port macquarie
# Processing Record 12 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto carreno
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | takoradi
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | ketchikan
# Processing Record 18 of Set 2 | vestmannaeyjar
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | lagoa
# Processing Record 22 of Set 2 | nabire
# Processing Record 23 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | swift current
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | karpathos
# Processing Record 30 of Set 2 | semirom
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | boueni
# Processing Record 33 of Set 2 | katangli
# Processing Record 34 of Set 2 | mineros
# Processing Record 35 of Set 2 | puerto madryn
# Processing Record 36 of Set 2 | okhotsk
# Processing Record 37 of Set 2 | kamaishi
# Processing Record 38 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 2 | turhal
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | lillesand
# Processing Record 43 of Set 2 | komsomolskiy
# Processing Record 44 of Set 2 | lorengau
# Processing Record 45 of Set 2 | kumbo
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | codrington
# Processing Record 50 of Set 2 | raglan
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | thap than
# Processing Record 3 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | ilheus
# Processing Record 12 of Set 3 | progreso
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | cotonou
# Processing Record 15 of Set 3 | santa cruz
# Processing Record 16 of Set 3 | tiruvannamalai
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | amazar
# Processing Record 22 of Set 3 | muncar
# Processing Record 23 of Set 3 | luderitz
# Processing Record 24 of Set 3 | port hedland
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | manta
# Processing Record 28 of Set 3 | ulaanbaatar
# Processing Record 29 of Set 3 | pouembout
# Processing Record 30 of Set 3 | corpus christi
# Processing Record 31 of Set 3 | tateyama
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | katsuura
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | whitecourt
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | kudahuvadhoo
# Processing Record 40 of Set 3 | niamtougou
# Processing Record 41 of Set 3 | barwala
# Processing Record 42 of Set 3 | alamosa
# Processing Record 43 of Set 3 | mataram
# Processing Record 44 of Set 3 | dunmore east
# Processing Record 45 of Set 3 | mount gambier
# Processing Record 46 of Set 3 | esperance
# Processing Record 47 of Set 3 | yabelo
# Processing Record 48 of Set 3 | faanui
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | mogadishu
# Processing Record 1 of Set 4 | alyangula
# Processing Record 2 of Set 4 | asosa
# Processing Record 3 of Set 4 | kharan
# Processing Record 4 of Set 4 | matay
# Processing Record 5 of Set 4 | aktau
# Processing Record 6 of Set 4 | yinchuan
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | irtyshskiy
# Processing Record 9 of Set 4 | safford
# Processing Record 10 of Set 4 | kananga
# Processing Record 11 of Set 4 | egvekinot
# Processing Record 12 of Set 4 | nemuro
# Processing Record 13 of Set 4 | koumac
# Processing Record 14 of Set 4 | hamilton
# Processing Record 15 of Set 4 | marsabit
# Processing Record 16 of Set 4 | aklavik
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | atuona
# Processing Record 19 of Set 4 | batamshinskiy
# Processing Record 20 of Set 4 | florianopolis
# Processing Record 21 of Set 4 | inta
# Processing Record 22 of Set 4 | port blair
# Processing Record 23 of Set 4 | viseu
# Processing Record 24 of Set 4 | launceston
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | kaitangata
# Processing Record 27 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | nador
# Processing Record 31 of Set 4 | el tocuyo
# Processing Record 32 of Set 4 | aksu
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | klaksvik
# Processing Record 35 of Set 4 | bowen
# Processing Record 36 of Set 4 | fort nelson
# Processing Record 37 of Set 4 | kenai
# Processing Record 38 of Set 4 | east london
# Processing Record 39 of Set 4 | saint-pierre
# Processing Record 40 of Set 4 | clyde river
# Processing Record 41 of Set 4 | gorno-altaysk
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | buala
# Processing Record 44 of Set 4 | guantanamo
# Processing Record 45 of Set 4 | sibolga
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | alice springs
# Processing Record 48 of Set 4 | mehamn
# Processing Record 49 of Set 4 | cap malheureux
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | beloha
# Processing Record 2 of Set 5 | chicama
# Processing Record 3 of Set 5 | canchungo
# Processing Record 4 of Set 5 | brae
# Processing Record 5 of Set 5 | puerto montt
# Processing Record 6 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 7 of Set 5 | chor
# Processing Record 8 of Set 5 | kudat
# Processing Record 9 of Set 5 | aranos
# Processing Record 10 of Set 5 | dong hoi
# Processing Record 11 of Set 5 | nioaque
# Processing Record 12 of Set 5 | ouadda
# Processing Record 13 of Set 5 | saint anthony
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | kasongo-lunda
# Processing Record 16 of Set 5 | mocuba
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | severo-kurilsk
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | phalaborwa
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 5 | la rioja
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | arman
# Processing Record 26 of Set 5 | tirumullaivasal
# Processing Record 27 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 28 of Set 5 | koungheul
# Processing Record 29 of Set 5 | pangnirtung
# Processing Record 30 of Set 5 | fernandez
# Processing Record 31 of Set 5 | chulman
# Processing Record 32 of Set 5 | baghdad
# Processing Record 33 of Set 5 | maun
# Processing Record 34 of Set 5 | bugaan
# Processing Record 35 of Set 5 | pangoa
# Processing Record 36 of Set 5 | roches noires
# City not found. Skipping...
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | kidal
# Processing Record 39 of Set 5 | skjervoy
# Processing Record 40 of Set 5 | espumoso
# Processing Record 41 of Set 5 | puerto pinasco
# City not found. Skipping...
# Processing Record 42 of Set 5 | uvat
# Processing Record 43 of Set 5 | husavik
# Processing Record 44 of Set 5 | kodiak
# Processing Record 45 of Set 5 | houma
# Processing Record 46 of Set 5 | dwarka
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | kabinda
# Processing Record 49 of Set 5 | huainan
# Processing Record 50 of Set 5 | port-gentil
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | dingle
# Processing Record 3 of Set 6 | pontal do parana
# Processing Record 4 of Set 6 | jiayuguan
# Processing Record 5 of Set 6 | airai
# Processing Record 6 of Set 6 | ben tre
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | stornoway
# Processing Record 10 of Set 6 | bakchar
# Processing Record 11 of Set 6 | san fernando
# Processing Record 12 of Set 6 | the valley
# Processing Record 13 of Set 6 | hilo
# Processing Record 14 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 6 | kloulklubed
# Processing Record 16 of Set 6 | katherine
# Processing Record 17 of Set 6 | auki
# Processing Record 18 of Set 6 | kaura namoda
# Processing Record 19 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 6 | arrecife
# Processing Record 21 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 6 | malartic
# Processing Record 23 of Set 6 | te anau
# Processing Record 24 of Set 6 | correntina
# Processing Record 25 of Set 6 | ossora
# Processing Record 26 of Set 6 | kisangani
# Processing Record 27 of Set 6 | acajutla
# Processing Record 28 of Set 6 | watertown
# Processing Record 29 of Set 6 | batemans bay
# Processing Record 30 of Set 6 | norman wells
# Processing Record 31 of Set 6 | mawlaik
# Processing Record 32 of Set 6 | naze
# Processing Record 33 of Set 6 | northam
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | listvyagi
# Processing Record 36 of Set 6 | araouane
# Processing Record 37 of Set 6 | quatre cocos
# Processing Record 38 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | vinh
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 6 | mar del plata
# Processing Record 45 of Set 6 | bathsheba
# Processing Record 46 of Set 6 | karlskrona
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | qasigiannguit
# Processing Record 49 of Set 6 | quelimane
# Processing Record 50 of Set 6 | den helder
# Processing Record 1 of Set 7 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | ostersund
# Processing Record 3 of Set 7 | varhaug
# Processing Record 4 of Set 7 | zlitan
# Processing Record 5 of Set 7 | hovd
# Processing Record 6 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 7 of Set 7 | narsaq
# Processing Record 8 of Set 7 | saint george
# Processing Record 9 of Set 7 | newport
# Processing Record 10 of Set 7 | pillaro
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | taltal
# Processing Record 13 of Set 7 | santa rita do passa quatro
# Processing Record 14 of Set 7 | uige
# Processing Record 15 of Set 7 | salinopolis
# Processing Record 16 of Set 7 | logrono
# Processing Record 17 of Set 7 | yakeshi
# Processing Record 18 of Set 7 | wagrowiec
# Processing Record 19 of Set 7 | alofi
# Processing Record 20 of Set 7 | ballina
# Processing Record 21 of Set 7 | hannibal
# Processing Record 22 of Set 7 | kruisfontein
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | predivinsk
# Processing Record 25 of Set 7 | talnakh
# Processing Record 26 of Set 7 | teguldet
# Processing Record 27 of Set 7 | constitucion
# Processing Record 28 of Set 7 | camacha
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | maniitsoq
# Processing Record 31 of Set 7 | zeerust
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | svetlyy
# Processing Record 34 of Set 7 | eureka
# Processing Record 35 of Set 7 | pemangkat
# Processing Record 36 of Set 7 | saravan
# Processing Record 37 of Set 7 | baruun-urt
# Processing Record 38 of Set 7 | sri aman
# Processing Record 39 of Set 7 | sept-iles
# Processing Record 40 of Set 7 | bhuj
# Processing Record 41 of Set 7 | zemio
# Processing Record 42 of Set 7 | feijo
# Processing Record 43 of Set 7 | koradacheri
# City not found. Skipping...
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | murgab
# Processing Record 46 of Set 7 | poum
# Processing Record 47 of Set 7 | kapoeta
# Processing Record 48 of Set 7 | bilibino
# Processing Record 49 of Set 7 | saint-philippe
# Processing Record 50 of Set 7 | oistins
# Processing Record 1 of Set 8 | rawson
# Processing Record 2 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 8 | oktyabrskiy
# Processing Record 4 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 5 of Set 8 | sao joao da barra
# Processing Record 6 of Set 8 | amuntai
# Processing Record 7 of Set 8 | bam
# Processing Record 8 of Set 8 | comodoro rivadavia
# Processing Record 9 of Set 8 | sabha
# Processing Record 10 of Set 8 | muzhi
# Processing Record 11 of Set 8 | buraydah
# Processing Record 12 of Set 8 | chernyshevskiy
# Processing Record 13 of Set 8 | berlevag
# Processing Record 14 of Set 8 | yenagoa
# Processing Record 15 of Set 8 | daniel flores
# Processing Record 16 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 8 | iguape
# Processing Record 18 of Set 8 | verkhnyaya toyma
# Processing Record 19 of Set 8 | coihaique
# Processing Record 20 of Set 8 | sola
# Processing Record 21 of Set 8 | tabou
# Processing Record 22 of Set 8 | kargasok
# Processing Record 23 of Set 8 | barreirinhas
# Processing Record 24 of Set 8 | kaka
# Processing Record 25 of Set 8 | pindi gheb
# Processing Record 26 of Set 8 | chotebor
# Processing Record 27 of Set 8 | xining
# Processing Record 28 of Set 8 | shache
# Processing Record 29 of Set 8 | sladkovo
# Processing Record 30 of Set 8 | pergine valsugana
# Processing Record 31 of Set 8 | iralaya
# Processing Record 32 of Set 8 | geraldton
# Processing Record 33 of Set 8 | necochea
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | naryan-mar
# Processing Record 36 of Set 8 | bilma
# Processing Record 37 of Set 8 | kaeo
# Processing Record 38 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 8 | padang
# Processing Record 40 of Set 8 | kalagarh
# Processing Record 41 of Set 8 | asmar
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | kuybysheve
# Processing Record 44 of Set 8 | seoul
# Processing Record 45 of Set 8 | goderich
# Processing Record 46 of Set 8 | havre-saint-pierre
# Processing Record 47 of Set 8 | santa cruz de la palma
# Processing Record 48 of Set 8 | verkhoyansk
# Processing Record 49 of Set 8 | cootamundra
# Processing Record 50 of Set 8 | banda aceh
# Processing Record 1 of Set 9 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | ottumwa
# Processing Record 4 of Set 9 | kerman
# Processing Record 5 of Set 9 | sinjar
# Processing Record 6 of Set 9 | mercedes
# Processing Record 7 of Set 9 | kondinskoye
# Processing Record 8 of Set 9 | fukue
# Processing Record 9 of Set 9 | lebedinyy
# Processing Record 10 of Set 9 | bejar
# Processing Record 11 of Set 9 | perbaungan
# Processing Record 12 of Set 9 | torres
# Processing Record 13 of Set 9 | sandwick
# Processing Record 14 of Set 9 | zelenchukskaya
# Processing Record 15 of Set 9 | acari
# Processing Record 16 of Set 9 | tongchuan
# Processing Record 17 of Set 9 | werda
# Processing Record 18 of Set 9 | zhoucun
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | sao filipe
# Processing Record 21 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 9 | namibe
# Processing Record 23 of Set 9 | inirida
# Processing Record 24 of Set 9 | nelson bay
# Processing Record 25 of Set 9 | awjilah
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | lompoc
# Processing Record 28 of Set 9 | vao
# Processing Record 29 of Set 9 | esperantinopolis
# Processing Record 30 of Set 9 | cidreira
# Processing Record 31 of Set 9 | asfi
# Processing Record 32 of Set 9 | bereda
# Processing Record 33 of Set 9 | grao mogol
# Processing Record 34 of Set 9 | yining
# Processing Record 35 of Set 9 | grand gaube
# Processing Record 36 of Set 9 | eyl
# Processing Record 37 of Set 9 | viedma
# Processing Record 38 of Set 9 | novovorontsovka
# Processing Record 39 of Set 9 | tilichiki
# Processing Record 40 of Set 9 | ola
# Processing Record 41 of Set 9 | angra
# City not found. Skipping...
# Processing Record 42 of Set 9 | obera
# Processing Record 43 of Set 9 | corrales
# Processing Record 44 of Set 9 | lebu
# Processing Record 45 of Set 9 | porto novo
# Processing Record 46 of Set 9 | birnin kebbi
# Processing Record 47 of Set 9 | la ronge
# Processing Record 48 of Set 9 | krasnaya yaruga
# Processing Record 49 of Set 9 | orguz
# Processing Record 50 of Set 9 | souillac
# Processing Record 1 of Set 10 | sakakah
# Processing Record 2 of Set 10 | ixtapa
# Processing Record 3 of Set 10 | kaoma
# Processing Record 4 of Set 10 | bolshevik
# Processing Record 5 of Set 10 | malakal
# Processing Record 6 of Set 10 | urumqi
# Processing Record 7 of Set 10 | kindu
# Processing Record 8 of Set 10 | saint-augustin
# Processing Record 9 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 10 | terney
# Processing Record 11 of Set 10 | liverpool
# Processing Record 12 of Set 10 | dhidhdhoo
# Processing Record 13 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 10 | taonan
# Processing Record 15 of Set 10 | ojinaga
# Processing Record 16 of Set 10 | honiara
# Processing Record 17 of Set 10 | vilhena
# Processing Record 18 of Set 10 | sao jose da coroa grande
# Processing Record 19 of Set 10 | hornepayne
# Processing Record 20 of Set 10 | shihezi
# Processing Record 21 of Set 10 | jumla
# Processing Record 22 of Set 10 | chimbote
# Processing Record 23 of Set 10 | ichhawar
# Processing Record 24 of Set 10 | dullewala
# Processing Record 25 of Set 10 | peniche
# Processing Record 26 of Set 10 | ariquemes
# Processing Record 27 of Set 10 | don sak
# Processing Record 28 of Set 10 | georgiyevka
# Processing Record 29 of Set 10 | marawi
# Processing Record 30 of Set 10 | mayari
# City not found. Skipping...
# Processing Record 31 of Set 10 | sinnamary
# Processing Record 32 of Set 10 | kayerkan
# Processing Record 33 of Set 10 | namikupa
# Processing Record 34 of Set 10 | acapulco
# Processing Record 35 of Set 10 | san ramon
# Processing Record 36 of Set 10 | chapais
# Processing Record 37 of Set 10 | cooma
# Processing Record 38 of Set 10 | havoysund
# Processing Record 39 of Set 10 | maunabo
# Processing Record 40 of Set 10 | belmonte
# Processing Record 41 of Set 10 | heishan
# Processing Record 42 of Set 10 | sayyan
# Processing Record 43 of Set 10 | lugovskiy
# City not found. Skipping...
# Processing Record 44 of Set 10 | andros town
# Processing Record 45 of Set 10 | olafsvik
# Processing Record 46 of Set 10 | wanaka
# Processing Record 47 of Set 10 | zhigansk
# Processing Record 48 of Set 10 | salalah
# Processing Record 49 of Set 10 | oranjestad
# Processing Record 50 of Set 10 | sioux lookout
# Processing Record 1 of Set 11 | abu samrah
# Processing Record 2 of Set 11 | santa isabel do rio negro
# Processing Record 3 of Set 11 | neuquen
# Processing Record 4 of Set 11 | ancud
# Processing Record 5 of Set 11 | winslow
# Processing Record 6 of Set 11 | oksfjord
# Processing Record 7 of Set 11 | bhinmal
# Processing Record 8 of Set 11 | kiama
# Processing Record 9 of Set 11 | trelew
# Processing Record 10 of Set 11 | sumenep
# Processing Record 11 of Set 11 | sungurlare
# Processing Record 12 of Set 11 | adrar
# Processing Record 13 of Set 11 | el carmen
# Processing Record 14 of Set 11 | mitsamiouli
# Processing Record 15 of Set 11 | shenjiamen
# Processing Record 16 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 11 | rocha
# Processing Record 18 of Set 11 | serabu
# Processing Record 19 of Set 11 | leshukonskoye
# Processing Record 20 of Set 11 | ngorongoro
# Processing Record 21 of Set 11 | vytegra
# Processing Record 22 of Set 11 | guerrero negro
# Processing Record 23 of Set 11 | manono
# Processing Record 24 of Set 11 | haines junction
# Processing Record 25 of Set 11 | empangeni
# Processing Record 26 of Set 11 | bandarbeyla
# Processing Record 27 of Set 11 | salisbury
# Processing Record 28 of Set 11 | daru
# Processing Record 29 of Set 11 | caluquembe
# Processing Record 30 of Set 11 | nieuw amsterdam
# Processing Record 31 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 32 of Set 11 | samdrup jongkhar
# Processing Record 33 of Set 11 | wenling
# Processing Record 34 of Set 11 | vuktyl
# Processing Record 35 of Set 11 | mayo
# Processing Record 36 of Set 11 | hirara
# Processing Record 37 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 11 | prince rupert
# Processing Record 39 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 11 | cabedelo
# Processing Record 41 of Set 11 | dryden
# Processing Record 42 of Set 11 | bintulu
# Processing Record 43 of Set 11 | khandyga
# Processing Record 44 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 45 of Set 11 | turukhansk
# Processing Record 46 of Set 11 | pundaguitan
# Processing Record 47 of Set 11 | cairns
# Processing Record 48 of Set 11 | broome
# Processing Record 49 of Set 11 | ugoofaaru
# Processing Record 50 of Set 11 | praia da vitoria
# Processing Record 1 of Set 12 | vila do maio
# Processing Record 2 of Set 12 | yamada
# Processing Record 3 of Set 12 | bodden town
# Processing Record 4 of Set 12 | kieta
# Processing Record 5 of Set 12 | usinsk
# Processing Record 6 of Set 12 | valleyview
# Processing Record 7 of Set 12 | muroto
# Processing Record 8 of Set 12 | nyurba
# Processing Record 9 of Set 12 | phulpur
# Processing Record 10 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 12 | dunedin
# Processing Record 12 of Set 12 | la baule-escoublac
# Processing Record 13 of Set 12 | ostrovnoy
# Processing Record 14 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 12 | ambilobe
# Processing Record 16 of Set 12 | kumphawapi
# Processing Record 17 of Set 12 | peleduy
# Processing Record 18 of Set 12 | ferme-neuve
# Processing Record 19 of Set 12 | beaverlodge
# Processing Record 20 of Set 12 | nchelenge
# Processing Record 21 of Set 12 | tuy hoa
# Processing Record 22 of Set 12 | maceio
# Processing Record 23 of Set 12 | huilong
# Processing Record 24 of Set 12 | esmeralda
# Processing Record 25 of Set 12 | rio gallegos
# Processing Record 26 of Set 12 | mildura
# Processing Record 27 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 12 | jonkoping
# Processing Record 29 of Set 12 | zilupe
# Processing Record 30 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 12 | san policarpo
# Processing Record 32 of Set 12 | majene
# Processing Record 33 of Set 12 | hami
# Processing Record 34 of Set 12 | hualmay
# Processing Record 35 of Set 12 | karonga
# Processing Record 36 of Set 12 | saint-joseph
# Processing Record 37 of Set 12 | wawa
# Processing Record 38 of Set 12 | taganak
# Processing Record 39 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 12 | nishihara
# Processing Record 41 of Set 12 | raga
# Processing Record 42 of Set 12 | gimbi
# Processing Record 43 of Set 12 | kiunga
# Processing Record 44 of Set 12 | kitgum
# Processing Record 45 of Set 12 | christchurch
# Processing Record 46 of Set 12 | walvis bay
# Processing Record 47 of Set 12 | bonavista
# Processing Record 48 of Set 12 | korla
# Processing Record 49 of Set 12 | prince albert
# Processing Record 50 of Set 12 | sokoni
# Processing Record 1 of Set 13 | yeppoon
# Processing Record 2 of Set 13 | soller
# Processing Record 3 of Set 13 | kaohsiung
# Processing Record 4 of Set 13 | myitkyina
# Processing Record 5 of Set 13 | solnechnyy
# Processing Record 6 of Set 13 | yei
# Processing Record 7 of Set 13 | galesong
# Processing Record 8 of Set 13 | marion
# Processing Record 9 of Set 13 | krupina
# Processing Record 10 of Set 13 | smithers
# Processing Record 11 of Set 13 | honningsvag
# Processing Record 12 of Set 13 | doha
# Processing Record 13 of Set 13 | omboue
# Processing Record 14 of Set 13 | yar-sale
# Processing Record 15 of Set 13 | da lat
# Processing Record 16 of Set 13 | galveston
# Processing Record 17 of Set 13 | sfantu gheorghe
# Processing Record 18 of Set 13 | la uribe
# City not found. Skipping...
# Processing Record 19 of Set 13 | piacabucu
# Processing Record 20 of Set 13 | bontang
# Processing Record 21 of Set 13 | karratha
# Processing Record 22 of Set 13 | carroll
# Processing Record 23 of Set 13 | balikpapan
# Processing Record 24 of Set 13 | namanga
# Processing Record 25 of Set 13 | kamyshlov
# Processing Record 26 of Set 13 | road town
# Processing Record 27 of Set 13 | galle
# Processing Record 28 of Set 13 | elban
# Processing Record 29 of Set 13 | kovin
# Processing Record 30 of Set 13 | belle fourche
# Processing Record 31 of Set 13 | riviere-au-renard
# Processing Record 32 of Set 13 | linapacan
# City not found. Skipping...
# Processing Record 33 of Set 13 | cockburn town
# Processing Record 34 of Set 13 | sakaiminato
# Processing Record 35 of Set 13 | kulhudhuffushi
# Processing Record 36 of Set 13 | khani
# Processing Record 37 of Set 13 | leningradskiy
# Processing Record 38 of Set 13 | banamba
# Processing Record 39 of Set 13 | kardla
# Processing Record 40 of Set 13 | tari
# Processing Record 41 of Set 13 | yantal
# Processing Record 42 of Set 13 | buchanan
# Processing Record 43 of Set 13 | jalu
# Processing Record 44 of Set 13 | porto santo
# Processing Record 45 of Set 13 | tomatlan
# Processing Record 46 of Set 13 | ruteng
# Processing Record 47 of Set 13 | gubkinskiy
# Processing Record 48 of Set 13 | camana
# Processing Record 49 of Set 13 | vabalninkas
# Processing Record 50 of Set 13 | along
# Processing Record 1 of Set 14 | sarti
# Processing Record 2 of Set 14 | yashkino
# Processing Record 3 of Set 14 | jieshi
# Processing Record 4 of Set 14 | ningan
# City not found. Skipping...
# Processing Record 5 of Set 14 | madimba
# Processing Record 6 of Set 14 | umm lajj
# Processing Record 7 of Set 14 | bahia de caraquez
# Processing Record 8 of Set 14 | la tuque
# Processing Record 9 of Set 14 | patacamaya
# Processing Record 10 of Set 14 | bumba
# Processing Record 11 of Set 14 | mahibadhoo
# Processing Record 12 of Set 14 | sorong
# Processing Record 13 of Set 14 | estaimpuis
# Processing Record 14 of Set 14 | bujaru
# Processing Record 15 of Set 14 | itaborai
# Processing Record 16 of Set 14 | skibbereen
# Processing Record 17 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 14 | santa fe
# Processing Record 19 of Set 14 | sambava
# Processing Record 20 of Set 14 | san carlos de bariloche
# Processing Record 21 of Set 14 | blankenburg
# Processing Record 22 of Set 14 | paraiso
# Processing Record 23 of Set 14 | slavsk
# Processing Record 24 of Set 14 | mandera
# Processing Record 25 of Set 14 | guane
# Processing Record 26 of Set 14 | fort beaufort
# Processing Record 27 of Set 14 | puerto escondido
# Processing Record 28 of Set 14 | sawtell
# Processing Record 29 of Set 14 | juneau
# Processing Record 30 of Set 14 | tukrah
# Processing Record 31 of Set 14 | strezhevoy
# Processing Record 32 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 33 of Set 14 | razole
# Processing Record 34 of Set 14 | ingham
# Processing Record 35 of Set 14 | uong bi
# Processing Record 36 of Set 14 | trincomalee
# Processing Record 37 of Set 14 | skoghall
# Processing Record 38 of Set 14 | coahuayana
# Processing Record 39 of Set 14 | sungurlu
# Processing Record 40 of Set 14 | asilah
# Processing Record 41 of Set 14 | beringovskiy
# Processing Record 42 of Set 14 | purpe
# Processing Record 43 of Set 14 | dzhebariki-khaya
# Processing Record 44 of Set 14 | mujiayingzi
# Processing Record 45 of Set 14 | bani walid
# Processing Record 46 of Set 14 | mackay
# Processing Record 47 of Set 14 | mastic beach
# Processing Record 48 of Set 14 | vila
# Processing Record 49 of Set 14 | garowe
# Processing Record 50 of Set 14 | talcahuano
# Processing Record 1 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 15 | zhezkazgan
# Processing Record 3 of Set 15 | port moresby
# Processing Record 4 of Set 15 | bima
# Processing Record 5 of Set 15 | teya
# Processing Record 6 of Set 15 | port washington
# Processing Record 7 of Set 15 | san joaquin
# Processing Record 8 of Set 15 | bubaque
# Processing Record 9 of Set 15 | burgeo
# Processing Record 10 of Set 15 | san juan de opoa
# Processing Record 11 of Set 15 | moose factory
# Processing Record 12 of Set 15 | ermelo
# Processing Record 13 of Set 15 | sibu
# Processing Record 14 of Set 15 | erzin
# Processing Record 15 of Set 15 | mwense
# Processing Record 16 of Set 15 | nouadhibou
# Processing Record 17 of Set 15 | nayoro
# Processing Record 18 of Set 15 | ruwi
# Processing Record 19 of Set 15 | phillaur
# Processing Record 20 of Set 15 | macau
# Processing Record 21 of Set 15 | grajau
# Processing Record 22 of Set 15 | rorvik
# Processing Record 23 of Set 15 | kodinsk
# Processing Record 24 of Set 15 | kapiri mposhi
# Processing Record 25 of Set 15 | beihai
# Processing Record 26 of Set 15 | chanika
# Processing Record 27 of Set 15 | tacuarembo
# Processing Record 28 of Set 15 | paamiut
# Processing Record 29 of Set 15 | zharkent
# Processing Record 30 of Set 15 | kabompo
# Processing Record 31 of Set 15 | barra do corda
# Processing Record 32 of Set 15 | robertson
# Processing Record 33 of Set 15 | scottsbluff
# Processing Record 34 of Set 15 | antalaha
# Processing Record 35 of Set 15 | dvinskoy
# Processing Record 36 of Set 15 | namatanai
# Processing Record 37 of Set 15 | discovery bay
# Processing Record 38 of Set 15 | chumikan
# Processing Record 39 of Set 15 | duma
# Processing Record 40 of Set 15 | ust-nera
# Processing Record 41 of Set 15 | abalak
# Processing Record 42 of Set 15 | portland
# Processing Record 43 of Set 15 | camabatela
# Processing Record 44 of Set 15 | imbituba
# Processing Record 45 of Set 15 | arcata
# Processing Record 46 of Set 15 | nkhata bay
# Processing Record 47 of Set 15 | lewistown
# Processing Record 48 of Set 15 | trinidad
# Processing Record 49 of Set 15 | palmer
# Processing Record 50 of Set 15 | saint andrews
# Processing Record 1 of Set 16 | moussoro
# Processing Record 2 of Set 16 | vila franca do campo
# Processing Record 3 of Set 16 | songea
# Processing Record 4 of Set 16 | novaya chigla
# Processing Record 5 of Set 16 | qaqortoq
# Processing Record 6 of Set 16 | leninsk
# Processing Record 7 of Set 16 | misratah
# Processing Record 8 of Set 16 | whittlesea
# Processing Record 9 of Set 16 | faridan
# City not found. Skipping...
# Processing Record 10 of Set 16 | toora-khem
# Processing Record 11 of Set 16 | derac
# Processing Record 12 of Set 16 | brigantine
# Processing Record 13 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 16 | shar
# Processing Record 15 of Set 16 | west bay
# Processing Record 16 of Set 16 | alekseyevsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bethel  41.3712  -73.4140     56.64        85         100        4.99
# 1      Colares  38.7992   -9.4469     60.76        88          47       23.00
# 2      Ushuaia -54.8000  -68.3000     46.06        53          20        3.44
# 3        Tiksi  71.6872  128.8694     18.77        88          67        7.94
# 4  Yellowknife  62.4560 -114.3525     54.12        76          75       11.50
# 5       Yulara -25.2406  130.9889     77.43        19         100       13.44
# 6       Kupang -10.1667  123.5833     86.47        59          21        5.57
# 7     Hermanus -34.4187   19.2345     58.50        69         100        2.86
# 8    Carnarvon -24.8667  113.6333     72.18        59           0       20.92
# 9      Ahipara -35.1667  173.1667     64.94        90          68       11.56
#
#   Country Current Description
# 0      US     overcast clouds
# 1      PT    scattered clouds
# 2      AR          few clouds
# 3      RU       broken clouds
# 4      CA       broken clouds
# 5      AU     overcast clouds
# 6      ID          few clouds
# 7      ZA     overcast clouds
# 8      AU           clear sky
# 9      NZ       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
reordered_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_list]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bethel      US  41.3712  -73.4140     56.64        85         100
# 1      Colares      PT  38.7992   -9.4469     60.76        88          47
# 2      Ushuaia      AR -54.8000  -68.3000     46.06        53          20
# 3        Tiksi      RU  71.6872  128.8694     18.77        88          67
# 4  Yellowknife      CA  62.4560 -114.3525     54.12        76          75
#
#    Wind Speed Current Description
# 0        4.99     overcast clouds
# 1       23.00    scattered clouds
# 2        3.44          few clouds
# 3        7.94       broken clouds
# 4       11.50       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
